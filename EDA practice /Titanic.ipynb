# %%
import pandas as pd

# Load Titanic dataset

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# %% [markdown]
# ## Data Understanding

# %%
#view first few rows

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#to measure no. of Rows and Column in the data
df.shape
# Out:
# (891, 12)

# %%
#non-numerics ("Object")

# %%
#checking tupes of data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# gives us the statistics of numeric data
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull()  #yesma kati null value cha ,missing value, yo gare purai memory khancha
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
# gives us the sum of number of null values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Columns name of the dataframe 
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# each value count
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df['Ticket'].value_counts() #yo ticket ko value
# Out:
# Ticket
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: count, Length: 681, dtype: int64

# %%
# Generates us the specific dataFrame
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 762          763         1       3           Barah, Mr. Hanna Assi    male
# 691          692         1       3              Karun, Miss. Manca  female
# 512          513         1       1       McGough, Mr. James Robert    male
# 534          535         0       3             Cacic, Miss. Marija  female
# 657          658         0       3   Bourke, Mrs. John (Catherine)  female
# 172          173         1       3    Johnson, Miss. Eleanor Ileen  female
# 491          492         0       3             Windelov, Mr. Einar    male
# 16            17         0       3            Rice, Master. Eugene    male
# 200          201         0       3  Vande Walle, Mr. Nestor Cyriel    male
# 535          536         1       2          Hart, Miss. Eva Miriam  female
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 762  20.0      0      0              2663   7.2292   NaN        C
# ...

# %%
# gives unique values
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.sort_values(by='Age').head(20)
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 831          832         1       2  Richards, Master. George Sibley    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 827          828         1       2            Mallet, Master. Andre    male
# 381          382         1       3      Nakid, Miss. Maria ("Mary")  female
# 164          165         0       3     Panula, Master. Eino Viljami    male
# 183          184         1       2        Becker, Master. Richard F    male
# ...

# %%
df.sort_values(by='Age',ascending=False).head(20)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 630          631         1       1       Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                        Svensson, Mr. Johan
# 493          494         0       1                    Artagaveytia, Mr. Ramon
# 96            97         0       1                  Goldschmidt, Mr. George B
# 116          117         0       3                       Connors, Mr. Patrick
# 672          673         0       2                Mitchell, Mr. Henry Michael
# 745          746         0       1               Crosby, Capt. Edward Gifford
# 33            34         0       2                      Wheadon, Mr. Edward H
# 54            55         0       1             Ostby, Mr. Engelhart Cornelius
# 280          281         0       3                           Duane, Mr. Frank
# 456          457         0       1                  Millet, Mr. Francis Davis
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.set_index('PassengerId',inplace=True)

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
# checking data types
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df.groupby('Pclass')['Age'].mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
df.Fare.head()
# Out:
# PassengerId
# 1     7.2500
# 2    71.2833
# 3     7.9250
# 4    53.1000
# 5     8.0500
# Name: Fare, dtype: float64

# %%
df['Fare']=df['Fare'].apply(lambda x :x*178)

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket        Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   1290.5000   NaN        S
# 2                1      0          PC 17599  12688.4274   C85        C
# ...

# %%
df['Embarked'].replace({'S':'Southampton','C':'Cherbourg','Q':'Queenstown'},inplace=True)
# Out:
# /var/folders/fh/ccbk_zrj50vdwyjmc8yf92080000gn/T/ipykernel_2120/491159221.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].replace({'S':'Southampton','C':'Cherbourg','Q':'Queenstown'},inplace=True)

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket        Fare Cabin     Embarked
# PassengerId
# 1                1      0         A/5 21171   1290.5000   NaN  Southampton
# 2                1      0          PC 17599  12688.4274   C85    Cherbourg
# ...

# %%
df.rename(columns={'SibSp':'Sibling_Spouse','Parch':'Parents_Child'},inplace=True)

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              Sibling_Spouse  Parents_Child            Ticket        Fare  \
# PassengerId
# 1                         1              0         A/5 21171   1290.5000
# 2                         1              0          PC 17599  12688.4274
# ...

# %%
df.rename(columns={'Fare':'Fare_Npr','Embarked':'Port'},inplace=True)

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              Sibling_Spouse  Parents_Child            Ticket    Fare_Npr  \
# PassengerId
# 1                         1              0         A/5 21171   1290.5000
# 2                         1              0          PC 17599  12688.4274
# ...

# %%
df.rename(columns={'Fare':'Fare_Npr','Embraked':'Port'})
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.reset_index
# Out:
# <bound method DataFrame.reset_index of              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              Sibling_Spouse  Parents_Child            Ticket    Fare_Npr  \
# PassengerId
# 1                         1              0         A/5 21171   1290.5000
# 2                         1              0          PC 17599  12688.4274
# ...

# %%
df_1=df[['Survived','Pclass','Age','Fare_Npr']]

# %%
df_1.corr()
# Out:
#           Survived    Pclass       Age  Fare_Npr
# Survived  1.000000 -0.338481 -0.077221  0.257307
# Pclass   -0.338481  1.000000 -0.369226 -0.549500
# Age      -0.077221 -0.369226  1.000000  0.096067
# Fare_Npr  0.257307 -0.549500  0.096067  1.000000

# %%
df_1.quantile(0.75)
# Out:
# Survived       1.0
# Pclass         3.0
# Age           38.0
# Fare_Npr    5518.0
# Name: 0.75, dtype: float64

# %%
df['Port'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
df_2=df['Age'].where(df['Age']>20)

# %%
df_2.sample(20)
# Out:
# PassengerId
# 707    45.0
# 105    37.0
# 310    30.0
# 366    30.0
# 393    28.0
# 299     NaN
# 703     NaN
# 565     NaN
# 582    39.0
# 82     29.0
# 612     NaN
# 635     NaN
# 62     38.0
# 281    65.0
# 90     24.0
# 60      NaN
# 536     NaN
# 248    24.0
# 466    38.0
# 517    34.0
# Name: Age, dtype: float64

# %% [markdown]
# ## Numpy

# %%
df.dtypes
# Out:
# Survived            int64
# Pclass              int64
# Name               object
# Sex                object
# Age               float64
# Sibling_Spouse      int64
# Parents_Child       int64
# Ticket             object
# Fare_Npr          float64
# Cabin              object
# Port               object
# dtype: object

# %%
import numpy as np

# %%
age=np.array(df['Age'])

# %%
np.isnan(age).sum()
# Out:
# 177

# %%
np.mean(age)
# Out:
# nan

# %%
np.mean(df['Fare_Npr'])
# Out:
# 5732.349018406285

# %%
np.median(df['Fare_Npr'])
# Out:
# 2572.8476

# %%
np.std(df['Fare_Npr'])
# Out:
# 8840.465131169785

# %% [markdown]
# ### Important

# %%
#Creating new feature
df['Age_Category']=np.where(df['Age']>18,'Adult','Child')
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              Sibling_Spouse  Parents_Child            Ticket    Fare_Npr  \
# PassengerId
# 1                         1              0         A/5 21171   1290.5000
# 2                         1              0          PC 17599  12688.4274
# ...

# %%
df.Age_Category.value_counts()
# Out:
# Age_Category
# Adult    575
# Child    316
# Name: count, dtype: int64

# %%
# HANDLING missing value with numpy

df['Age']=df['Age'].fillna(np.mean(df['Age']))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Survived        891 non-null    int64
#  1   Pclass          891 non-null    int64
#  2   Name            891 non-null    object
#  3   Sex             891 non-null    object
#  4   Age             891 non-null    float64
#  5   Sibling_Spouse  891 non-null    int64
#  6   Parents_Child   891 non-null    int64
#  7   Ticket          891 non-null    object
#  8   Fare_Npr        891 non-null    float64
#  9   Cabin           204 non-null    object
#  10  Port            889 non-null    object
#  11  Age_Category    891 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 90.5+ KB

# %%
#Advanced Grouping and Aggregation
df_grouped=df.groupby('Pclass).agg({
    'Age':['mean','median'],
    'Fare_Npr':['mean','median']
})
# Out:
#   Cell In[59], line 2
#     df_grouped=df.groupby('Pclass).agg({
#                           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
df_grouped

# %%
df.info()

# %%
df=df.drop('Cabin',axis=1)

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Survived        889 non-null    int64
#  1   Pclass          889 non-null    int64
#  2   Name            889 non-null    object
#  3   Sex             889 non-null    object
#  4   Age             889 non-null    float64
#  5   Sibling_Spouse  889 non-null    int64
#  6   Parents_Child   889 non-null    int64
#  7   Ticket          889 non-null    object
#  8   Fare_Npr        889 non-null    float64
#  9   Port            889 non-null    object
#  10  Age_Category    889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.3+ KB

# %%
df.to_csv('data/titanic.csv', index=True)
