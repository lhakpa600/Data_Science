# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1. Understand Data

# %% [markdown]
# ##### Load Dataset

# %%
tips=sns.load_dataset('tips')

# %% [markdown]
# ##### Inspect the Data

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# ### 2. Shapes and Data Types

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ### 3. Data Cleaning

# %%
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
tips.duplicated().sum()
# Out:
# 1

# %%
tips.duplicated().sum
# Out:
# <bound method Series.sum of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool>

# %% [markdown]
# ### 4. Univariate Analysis

# %% [markdown]
# ##### Numerical columns

# %%
sns.histplot(tips['total_bill'])
plt.title('Distribution of Total Bill')
# Out:
# Text(0.5, 1.0, 'Distribution of Total Bill')

# %%
sns.histplot(tips['sex'])
plt.title('Distribution of tips')
# Out:
# Text(0.5, 1.0, 'Distribution of tips')

# %%
sns.histplot(tips['tip'])
plt.title('Distribution of tip')
# Out:
# Text(0.5, 1.0, 'Distribution of tip')

# %%
sns.boxplot(x=tips['tip'])
plt.title('Boxplot of Tip Amount')  #outlier cha9,10, jun mean banda derrai tada cha
# Out:
# Text(0.5, 1.0, 'Boxplot of Tip Amount')

# %%
sns.boxplot(x=tips['size'])
plt.title('Boxplot of Size')
# Out:
# Text(0.5, 1.0, 'Boxplot of Size')

# %% [markdown]
# #### Categorical Columns

# %%
sns.countplot(x='day',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x='smoker',data=tips)
plt.title('count observation of smoker')
# Out:
# Text(0.5, 1.0, 'count observation of smoker')

# %%
ab=np.array([18,19,17,17,180])  #180 value is outlier mena banda ekdum tada

# %%
ab.mean() #yo invalid data huncha mean 50 jun tesma 50 banne value nai chaina,calculation is right
# Out:
# 50.2

# %%
# tesaile boxplot use garcha

# %% [markdown]
# ### 5. Bivariate Analysis

# %% [markdown]
# #### Numerical- Numerical Relationship

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips,hue='tip',palette='coolwarm')
plt.title('Total Bill vs Tip')
plt.show()

# %%
tips.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
cor=tips.corr(numeric_only=True)

sns.heatmap(cor,annot=True,cmap='coolwarm')
plt.title('correlation between numerical values')
# Out:
# Text(0.5, 1.0, 'correlation between numerical values')

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# ##### Numerical -Categorical Relationship

# %%
sns.boxplot(x='sex',y='tip',data=tips)
plt.title('Tip amount based on Gender')
# Out:
# Text(0.5, 1.0, 'Tip amount based on Gender')

# %%
sns.boxplot(x='smoker',y='tip',data=tips)
plt.title('Tip amount based on Smoking habit')
# Out:
# Text(0.5, 1.0, 'Tip amount based on Smoking habit')

# %%
sns.violinplot(x='smoker',y='tip',data=tips)
plt.title('Tip amount based on smoking habit ')
# Out:
# Text(0.5, 1.0, 'Tip amount based on smoking habit ')

# %% [markdown]
# ##### Categorial- Categorial

# %%
sns.countplot(x='day', hue='time', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %% [markdown]
# ### 6. Multivariate analysis

# %%
sns.pairplot(tips,hue='sex')

# %% [markdown]
# #### 6. Grouping and Aggregation

# %%
tips.groupby('sex')['tip'].mean()
# Out:
# /var/folders/fh/ccbk_zrj50vdwyjmc8yf92080000gn/T/ipykernel_25795/2929813174.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby('sex')['tip'].mean()
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
tips.groupby('day').agg({'total_bill':'mean','tip':'mean'})
# Out:
# /var/folders/fh/ccbk_zrj50vdwyjmc8yf92080000gn/T/ipykernel_25795/3775092670.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby('day').agg({'total_bill':'mean','tip':'mean'})
#       total_bill       tip
# day
# Thur   17.682742  2.771452
# Fri    17.151579  2.734737
# Sat    20.441379  2.993103
# Sun    21.410000  3.255132

# %%
tips.groupby(['sex','day'])['tip'].mean()
# Out:
# /var/folders/fh/ccbk_zrj50vdwyjmc8yf92080000gn/T/ipykernel_25795/1596412272.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby(['sex','day'])['tip'].mean()
# sex     day
# Male    Thur    2.980333
#         Fri     2.693000
#         Sat     3.083898
#         Sun     3.220345
# Female  Thur    2.575625
#         Fri     2.781111
#         Sat     2.801786
#         Sun     3.367222
# Name: tip, dtype: float64

# %% [markdown]
# ### 7. Feature Engineering

# %%
## tips ko rati % chai tip diyeko rai cha herna 

tips['tip_percent']=(tips['tip']/tips['total_bill']) *100

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_percent
# 0       16.99  1.01  Female     No  Sun  Dinner     2     5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3    16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3    16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2    13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4    14.680765

# %%
sns.histplot(tips['tip_percent'],kde=True)
plt.title('Distribution of tip percent')
# Out:
# Text(0.5, 1.0, 'Distribution of tip percent')

# %%
tips['tip_percent'].describe()
# Out:
# count    244.000000
# mean      16.080258
# std        6.107220
# min        3.563814
# 25%       12.912736
# 50%       15.476977
# 75%       19.147549
# max       71.034483
# Name: tip_percent, dtype: float64

# %% [markdown]
# ##### Using domain knowledge

# %%
tips_adjusted=tips[tips['tip_percent']<40]  #outlier hataune

# %%
tips_adjusted['tip_percent'].describe()
# Out:
# count    242.000000
# mean      15.747446
# std        4.716886
# min        3.563814
# 25%       12.853825
# 50%       15.408357
# 75%       18.995586
# max       32.573290
# Name: tip_percent, dtype: float64

# %% [markdown]
# #### Using Interquartile range

# %% [markdown]
# ##### Calculating quartiles

# %% [markdown]
# Q1=tips['total_bill'].quantile(0.25)
# Q3=tips['total_bill'].quantile (0.75)

# %%
Q1
# Out:
# 13.3475

# %%
Q3
# Out:
# 24.127499999999998

# %% [markdown]
# ##### Calculating IQR (Inter Quartile Range)

# %%
IQR= Q3-Q1

# %%
IQR
# Out:
# 10.779999999999998

# %% [markdown]
# #### Boundaries Defining

# %%
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

# %%
lower_bound
# Out:
# -2.8224999999999945

# %%
upper_bound
# Out:
# 40.29749999999999

# %%
tips_clean=tips[(tips['total_bill']>=lower_bound) & (tips['total_bill'])
# Out:
#   Cell In[291], line 1
#     tips_clean=tips[(tips['total_bill']>=lower_bound) & (tips['total_bill'])
#                                                                             ^
# SyntaxError: incomplete input

# %%
tips_clean['total_bill'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[294], line 1
# ----> 1 tips_clean['total_bill'].describe()
#
# NameError: name 'tips_clean' is not defined
